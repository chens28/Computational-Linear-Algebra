# %% [markdown]
# # Polynomial regression as linear least squares
#
# From the knowledge of a sample of pair of scalar values $\{a_i, y_i\}_{i=1}^n$, we would like to predict the relation between $x$ and $y$. One simple way to go beyond linear regression is to consider polynomial regression: for example we could try to model $y$ as a polynomial of degree 3 of $a$. We would look for $(x_0, x_1, x_2, x_3) \in \mathbb{R}^4$ such that the values $a_i$ and $y_i$ are linked as $y_i \simeq x_0 + x_1 a_i + x_2 a_i^2$.
#
# This problem can be mapped to linear regression by considering that we have for each $a$ a feature vectors of dimension $d + 1$ when considering the fit of a polynomial of degree $d$. This feature vector is $(1, a, a^2, \cdots, a^d)$. Such that the full data matrix is
# $$
#     A = \left[\begin{matrix}
#     1 & a_1 & \cdots & a_1^d \\
#     1 & a_2 & \cdots & a_2^d \\
#     \vdots & \vdots & \vdots & \vdots \\
#     1 & a_n & \cdots & a_n^d
# \end{matrix} \right] \in \mathbb{R}^{n \times (d+1)}.
# $$
#
# As a exercise below we will consider data that was created from a polynomial of dimension 3, to which noise is added. Assuming that we do not know the degree of the generated polynomial, we will try to fit with $d = 5$ and $d=2$ and investigate ridge regression.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## Helper functions to setup the problem
def get_data_mat(a, deg):
    """
    Inputs:
    a: (np.array of size N)
    deg: (int) max degree used to generate the data matrix
    
    Returns:
    A: (np.array of size N x (deg_true + 1)) data matrix
    """
    A = np.array([a ** i for i in range(deg + 1)]).T
    return A

def draw_sample(deg_true, x, N, eps=0):
    """
    Inputs:
    deg_true: (int) degree of the polynomial g
    a: (np.array of size deg_true) parameter of g
    N: (int) size of sample to draw
    eps: noise level
    
    Returns:
    x: (np.array of size N)
    y: (np.array of size N)
    """    
    a = np.sort(np.random.rand(N))
    A = get_data_mat(a, deg_true)
    y = A @ x + eps * np.random.randn(N)
    return a, y

# %% [markdown]
# **(a)** Complete the three functions below to obtain
# - the least square estimator $x^{LS}$
# - the ridge estimator $x^{Ridge}$
# - the mean square error $\lVert A x - y \rVert^2 / n$

# %%
def least_square_estimator(A, y):
    x_ls = np.linalg.pinv(A) @ y
    return x_ls

def ridge_estimator(A, y, lbd):
    x_ridge = np.linalg.inv(A.T@A + lbd*np.eye((A.T@A).shape[0])) @ A.T @ y
    return x_ridge

def mean_squared_error(x, A, y):
    mse = (np.linalg.norm(A@x - y)**2) / A.shape[0]
    return mse

# %%
# This cells generates the data - for your submission do not change it. 
# But for your own curiosity, do not hesistate to investigate what is going on when changing the properties of the data :) 

np.random.seed(45) # fixing seed so everyone should see the same data
N = 10
deg_true = 3 # degree of true polynomial
eps = 0.5 # noise amplitude
x_true = np.array([-3.75307359,  6.58178662,  6.23070014, -8.02457871])

# radom input data
a_tr, y_tr = draw_sample(deg_true, x_true, N, eps=eps) # training data
a_te, y_te = draw_sample(deg_true, x_true, 2 * N, eps=eps) # testing data

a_plot = np.linspace(0, 1, 100)
A_plot = get_data_mat(a_plot, deg_true)
plt.plot(a_tr, y_tr,'o', label='train')
plt.plot(a_te, y_te,'o', label='test')
plt.plot(a_plot, A_plot @ x_true,'-', label='true')
plt.legend()

# %% [markdown]
# **(b)** Complete the code below to visualize the prediction of $x^{LS}$ and $x^{Ridge}$ for $\lambda$ in $[1e-7, 0.1, 1]$, using in all cases a prediction model of degree 5. The output of the cell should be a plot as above, where you added three lines of predictions for all values of $a \in [0,1]$: line LS, line ridge $\lambda = 1e-7$, line ridge $\lambda = 0.1$, line ridge $\lambda = 1$.

# %%
a_plot = np.linspace(0, 1, 100)
A_plot = get_data_mat(a_plot, deg_true)
plt.plot(a_tr, y_tr,'o', label='train')
plt.plot(a_te, y_te,'o', label='test')
plt.plot(a_plot, A_plot @ x_true,'-', label='true')

deg_pred = 5

A_tr = get_data_mat(a_tr, deg_pred)
A_te = get_data_mat(a_te, deg_pred)

x_ls = least_square_estimator(A_tr, y_tr)

A_plot = get_data_mat(a_plot, deg_pred)
plt.plot(a_plot, A_plot @ x_ls, label='LS')

for lbd in [1e-7, 0.1, 1]:
    x_rg = ridge_estimator(A_tr, y_tr, lbd)
    plt.plot(a_plot, A_plot @ x_rg, label='RG: lbd='+ str(lbd))
plt.legend()

# %% [markdown]
# **(c)** Use the `mean_squared_error` to make a plot of the training error and the test error as a function of $\lambda$ as we have seen in the lecture (range given below). Which value of $\lambda$ would you choose? Does that align with your intuition from the plots above?

# %%
tr_mse = []
te_mse = []
lbds = np.logspace(-6, -1, 10)
for lbd in lbds:
    x = ridge_estimator(A_tr, y_tr, lbd)
    tr_mse.append(mean_squared_error(x, A_tr, y_tr))
    te_mse.append(mean_squared_error(x, A_te, y_te))

plt.plot(lbds, tr_mse, '-+', label='train')
plt.plot(lbds, te_mse,'-+', label='test')
plt.xscale('log')
plt.legend()

# %%
best_i = np.argmin(te_mse)
best_lbd = lbds[best_i]
print(f'optimal value of lambda is {best_lbd}')
# Out:
# optimal value of lambda is 0.0005994842503189409

# %% [markdown]
# Based on the plot of training error and the test error, I would choose a 𝜆 of around 0.0006 as it is the minimizer for the test error as a function of 𝜆.
#
# It does not align with my intuition from the parts before. From the plot in part b), My intuition for the optimal 𝜆 would be 0.1 as the line with 𝜆 = 0.1 (brown line) seems to be closest line to the true line (green line) among the 3 ridge regression lines.

# %% [markdown]
# **(d)** For the optimal value of $\lambda$ compare $x^{LS}$, $x^{Ridge}$ and $x^{true}$.

# %%
x_rg=ridge_estimator(A_tr, y_tr, best_lbd)

print(f'x_LS: {x_ls} \n')
print(f'x_RIDGE: {x_rg} \n')
print(f'x_true: {x_true}')
# Out:
# x_LS: [  -3.93364285   22.52325288 -156.62130069  526.55826593 -704.77022878
#   317.95651726]
#
# x_RIDGE: [-3.33597562  4.00682033  5.19992611 -0.54143152 -2.72424644 -1.5734486 ]
#
# x_true: [-3.75307359  6.58178662  6.23070014 -8.02457871]

# %%
# Train set MSE
print('x_LS:', mean_squared_error(x_ls, A_tr, y_tr))
print('x_RIDGE:',mean_squared_error(x_rg, A_tr, y_tr))
print('x_true:',mean_squared_error(np.append(x_true, [0,0]), A_tr, y_tr))
# Out:
# x_LS: 0.10527604852565331
# x_RIDGE: 0.12680480520928686
# x_true: 0.20598040067060452

# %%
# Test set MSE
print('x_LS:', mean_squared_error(x_ls, A_te, y_te))
print('x_RIDGE:',mean_squared_error(x_rg, A_te, y_te))
print('x_true:',mean_squared_error(np.append(x_true, [0,0]), A_te, y_te))
# Out:
# x_LS: 1.366196839672586
# x_RIDGE: 0.1743484790525785
# x_true: 0.1779781795014497

# %% [markdown]
# $x^{LS}$ and $x^{Ridge}$ has 6 betas because we are fitting a degree 5 polynomial regression and $x^{true}$ has 4 betas because the generated polynomial regression model has degree of 3.
#
# If we fill the two missing terms in $x^{LS}$ with 0s, it is obvious that the $x^{Ridge}$ is much closer to $x^{true}$ compared with $x^{LS}$. All betas of $x^{Ridge}$ is less than 10 while 4 betas within $x^{LS}$ were over 100.
#
# From a peformance perspective, when evaluated on the training set, $x^{LS}$ outputs the smallest MSE, followed by $x^{Ridge}$. $x^{true}$ outputs the largest MSE. When evaluated on the test set, $x^{Ridge}$ outputs the smallest MSE, followed by$x^{true}$. $x^{Ridge}$ ouptuts a siginificantly larger MSE. For $x^{LS}$ and $x^{Ridge}$, the test sets output a larger MSE (compared to traning set) with $x^{LS}$'s being significantly larger and $x^{Ridge}$'s being only slightly larger. For $x^{true}$, the test sets output a smaller MSE (compared to traning set).
#
# We could see that $x^{LS}$ is overfitting the training data, and $x^{Ridge}$ generalize better to unseen data.

# %% [markdown]
# (e) Repeat the same operation with a fitting model of degree 2 (`deg_pred=2`). What are your findings related to the optimal degree of regularizations in this case?

# %%
a_plot = np.linspace(0, 1, 100)
A_plot = get_data_mat(a_plot, deg_true)
plt.plot(a_tr, y_tr,'o', label='train')
plt.plot(a_te, y_te,'o', label='test')
plt.plot(a_plot, A_plot @ x_true,'-', label='true')

deg_pred = 2

A_tr = get_data_mat(a_tr, deg_pred)
A_te = get_data_mat(a_te, deg_pred)

x_ls = least_square_estimator(A_tr, y_tr)

A_plot = get_data_mat(a_plot, deg_pred)
plt.plot(a_plot, A_plot @ x_ls, label='LS')

for lbd in [1e-7, 0.1, 1]:
    x_rg = ridge_estimator(A_tr, y_tr, lbd)
    plt.plot(a_plot, A_plot @ x_rg, label='RG:'+ str(lbd))
plt.legend()

# %%
tr_mse = []
te_mse = []
lbds = np.logspace(-6, -1, 10)
for lbd in lbds:
    x = ridge_estimator(A_tr, y_tr, lbd)
    tr_mse.append(mean_squared_error(x, A_tr, y_tr))
    te_mse.append(mean_squared_error(x, A_te, y_te))

plt.plot(lbds, tr_mse, '-+', label='train')
plt.plot(lbds, te_mse,'-+', label='test')
plt.xscale('log')
plt.legend()

# %% [markdown]
# When fitting model of degree 2 (deg_pred=2). The optimal 𝜆 would be the smallest value possible based on both of the plots above. In the regression lines plot, the optimal 𝜆 would be 1𝑒−7 as the line with 𝜆 = 1𝑒−7 (purple line) seems to be closest line to the true line (green line) among the 3 lasso regression lines.
#
# Based on the plot of training error and the test error, I would choose a 𝜆 that it is cloest to 0 as test error as a function of 𝜆 is monotonic increasing.
#
# Therefore, the optimal 𝜆 would be 0, and the optimal degree of regularizations would be none in this case.
